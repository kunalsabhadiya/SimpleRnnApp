# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent = [
    'the glass of milk',
    'the glass of orange juice',
    'the glass of water',
    'the cup of tea',
    'understand the meaning of life',
    'the meaning of life is to live it'
        ]

# %%
voc_size = 10000
one_hot_sent = [one_hot(words,voc_size) for words in sent]
one_hot_sent
# Out:
# [[7500, 3448, 3433, 8109],
#  [7500, 3448, 3433, 2124, 8819],
#  [7500, 3448, 3433, 4980],
#  [7500, 483, 3433, 2207],
#  [7670, 7500, 9894, 3433, 7598],
#  [7500, 9894, 3433, 7598, 1648, 8844, 1983, 7351]]

# %%
## Word Embedding Representation

from tensorflow.keras.layers import Embedding
##from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length = 10
embedded_docs = pad_sequences(one_hot_sent, maxlen=sent_length, padding='pre')
embedded_docs
# Out:
# array([[   0,    0,    0,    0,    0,    0, 7500, 3448, 3433, 8109],
#        [   0,    0,    0,    0,    0, 7500, 3448, 3433, 2124, 8819],
#        [   0,    0,    0,    0,    0,    0, 7500, 3448, 3433, 4980],
#        [   0,    0,    0,    0,    0,    0, 7500,  483, 3433, 2207],
#        [   0,    0,    0,    0,    0, 7670, 7500, 9894, 3433, 7598],
#        [   0,    0, 7500, 9894, 3433, 7598, 1648, 8844, 1983, 7351]],
#       dtype=int32)

# %%
dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size, dim, input_length=sent_length))
model.compile('adam', 'mse')

# %%
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_7 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# array([[[-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.00518866,  0.00310296, -0.00432601,  0.03358385,
#          -0.01632341,  0.01042169, -0.00332571, -0.02440727,
#          -0.04137228, -0.01952591],
#         [-0.0447669 ,  0.02121357,  0.04789269, -0.0140679 ,
#          -0.03467279, -0.03697635,  0.04066041, -0.03001502,
#           0.02231392,  0.02339583],
#         [ 0.0482991 , -0.04022903, -0.03623969,  0.03503791,
#           0.02680181,  0.04368693,  0.01136682, -0.01076814,
#           0.02242735, -0.04336617],
#         [-0.00518866,  0.00310296, -0.00432601,  0.03358385,
#          -0.01632341,  0.01042169, -0.00332571, -0.02440727,
#          -0.04137228, -0.01952591],
#         [-0.0447669 ,  0.02121357,  0.04789269, -0.0140679 ,
#          -0.03467279, -0.03697635,  0.04066041, -0.03001502,
#           0.02231392,  0.02339583],
#         [ 0.0482991 , -0.04022903, -0.03623969,  0.03503791,
#           0.02680181,  0.04368693,  0.01136682, -0.01076814,
#           0.02242735, -0.04336617],
#         [ 0.04427438,  0.02328723, -0.00990946,  0.00915047,
#           0.0262883 ,  0.04046782,  0.02107162,  0.0125749 ,
#           0.0161497 , -0.04247138]],
#
#        [[-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.00518866,  0.00310296, -0.00432601,  0.03358385,
#          -0.01632341,  0.01042169, -0.00332571, -0.02440727,
#          -0.04137228, -0.01952591],
#         [-0.01212846,  0.02992262, -0.0373962 , -0.04289423,
#          -0.01614089,  0.02507902,  0.00906756, -0.04945778,
#          -0.01153014,  0.04228753],
#         [ 0.0482991 , -0.04022903, -0.03623969,  0.03503791,
#           0.02680181,  0.04368693,  0.01136682, -0.01076814,
#           0.02242735, -0.04336617],
#         [-0.03848695,  0.03470125, -0.0220701 ,  0.00932394,
#          -0.00122743,  0.01909859,  0.03483171, -0.03246849,
#           0.02872011,  0.02035118]],
#
#        [[-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.01164713,  0.03701185,  0.04622045,  0.01494657,
#          -0.0042603 ,  0.00428715,  0.04774935,  0.02867821,
#          -0.01616462, -0.03846116],
#         [-0.00518866,  0.00310296, -0.00432601,  0.03358385,
#          -0.01632341,  0.01042169, -0.00332571, -0.02440727,
#          -0.04137228, -0.01952591],
#         [ 0.03711188,  0.00925542, -0.01422706, -0.03304034,
#          -0.0363128 , -0.02837635, -0.04207907, -0.03313035,
#          -0.03962434, -0.03801845],
#         [ 0.0482991 , -0.04022903, -0.03623969,  0.03503791,
#           0.02680181,  0.04368693,  0.01136682, -0.01076814,
#           0.02242735, -0.04336617],
#         [-0.01646521,  0.01972581, -0.02524332,  0.0023932 ,
#           0.0416446 , -0.01810042,  0.0132756 ,  0.0448115 ,
#          -0.04839624,  0.02608189]],
#
#        [[-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.04775841, -0.00151328, -0.01316126,  0.01522377,
#          -0.02422231, -0.01284029, -0.00789884,  0.03927598,
#           0.02746208, -0.03585353],
#         [-0.00518866,  0.00310296, -0.00432601,  0.03358385,
#          -0.01632341,  0.01042169, -0.00332571, -0.02440727,
#          -0.04137228, -0.01952591],
#         [ 0.03711188,  0.00925542, -0.01422706, -0.03304034,
#          -0.0363128 , -0.02837635, -0.04207907, -0.03313035,
#          -0.03962434, -0.03801845],
#         [ 0.0482991 , -0.04022903, -0.03623969,  0.03503791,
#           0.02680181,  0.04368693,  0.01136682, -0.01076814,
#           0.02242735, -0.04336617],
#         [-0.01646521,  0.01972581, -0.02524332,  0.0023932 ,
#           0.0416446 , -0.01810042,  0.0132756 ,  0.0448115 ,
#          -0.04839624,  0.02608189],
#         [-0.0243336 ,  0.00867331,  0.03204937,  0.03408234,
#           0.01547437,  0.00267712, -0.0424138 ,  0.03598882,
#           0.02268985, -0.04475652],
#         [ 0.029955  ,  0.00771232,  0.03685868,  0.01419077,
#          -0.01508407,  0.02288244,  0.03380438, -0.03739911,
#           0.04240337, -0.00475847],
#         [ 0.00666528, -0.04866982, -0.01939811, -0.04194292,
#           0.01227933,  0.01043215,  0.03330998,  0.02802572,
#          -0.01770503, -0.02767842],
#         [-0.00267357, -0.03382957, -0.00021888,  0.04537728,
#          -0.04498682, -0.00495362, -0.01550579, -0.0298324 ,
#           0.01889132, -0.04044707]]], dtype=float32)
